# %%
from lark import Tree, Lark

# %%
def unwrap(tree):
    lines = []
    lastLineEnd = 0
    
    indent = 0
    
    text = str(tree)
    
    for i, c in enumerate(text):
        if text[i:].startswith('), ['):
            lines.append((indent * '  ') + text[lastLineEnd:i + 4].strip())
            lastLineEnd = i + 4
            indent += 1
            
        elif c == ']':
            lines.append((indent * '  ') + text[lastLineEnd:i].strip())
            lastLineEnd = i
            indent -= 1
            
        elif text[i:].startswith('), '):
            lines.append((indent * '  ') + text[lastLineEnd:i + 2].strip())
            lastLineEnd = i + 2
                    
    return '\n'.join(lines)

# %%
grammar = r'''
// sectioning

_CHAPTER_TAG: "!"
_SECTION_TAG: "!!"
_SUBSECTION_TAG: "!!!"
_SUBSUBSECTION_TAG: "!!!!"

TITLE: /[^\n`]+/

// block

_BLOCK_TAG: "@"
BLOCK_TYPE_TAG: /[A-Za-z0-9]+/
_BLOCK_TAG_SEPPARATOR: ":"
_BLOCK_END: /\n[ \t]*(?=\n[ \t]*\n)/

// whitespace

SPACE: " "
DOUBLE_SPACE: "  "
TRIPLE_SPACE: "   "
TAB: /\t/

INLINE_WHITESPACE: _INLINE_WHITESPACE
inline_whitespace: (TRIPLE_SPACE | DOUBLE_SPACE | SPACE | TAB)+
_INLINE_WHITESPACE: (TRIPLE_SPACE | DOUBLE_SPACE | SPACE | TAB)+

NEWLINE: _NEWLINE
_NEWLINE: /\n/

// center

CENTER_OPEN: ">"
CENTER_CLOSE: "<" 

// comment

COMMENT_DELIMITER: "##"
COMMENT_TEXT: /([^#]|((?<!#)#(?!#)))+/

// math block

MATH_BLOCK_DELIMITER: _MATH_BLOCK_DELIMITER
_MATH_BLOCK_DELIMITER: /(?!<`)`(?!`)/

// table

TABLE_DELIMITER: "||" | "|"
TABLE_SEPPARATOR: "|--" /[^(\n)]*/

// text

SPECIAL_LETTER: /[ěščřžýáíéďňťóúůöĚŠČŘŽÝÁÍÉĎŇŤÓÚŮÖ]/
PASSIVE_CHARACTER: /[a-zA-Z0-9\(\)\[\]\.,~\+\*\/:;'"_\?&\%]|((?<!#)#(?!#))/ | SPECIAL_LETTER
WORD: (LETTER | NUMBER | SPECIAL_LETTER | /[\(\)\[\]\.,\!@~\-\+\*\/:;'"_\?&\%]|((?<!#)#(?!#))/  )+
FIRST_WORD: PASSIVE_CHARACTER WORD?

text: INLINE_WHITESPACE? WORD (INLINE_WHITESPACE WORD)* INLINE_WHITESPACE?
sanitized_text: INLINE_WHITESPACE? FIRST_WORD (INLINE_WHITESPACE WORD)* INLINE_WHITESPACE?

// list

SIMPLE_LIST_BULLET: /\-(?!{)/
COMPOSITE_LIST_BULLET: "-{"

// image

IMAGE: "\\image" /\[[^\]]*\]/? "{" /[^}]+/ "}"


////////////////////////////////////////////////////////////////////////

start: (_INLINE_WHITESPACE | _NEWLINE)* (_object NEWLINE+)* _object (_INLINE_WHITESPACE | _NEWLINE)*

title: (TITLE | INLINE_WHITESPACE | math_block)+

_object: (chapter_header | section_header | subsection_header | subsubsection_header | list_item | block | table | center | content)
_inline_object: (chapter_header | section_header | subsection_header | subsubsection_header | list_item | block | table | center | inline_content)

content: INLINE_WHITESPACE? (image | comment | sanitized_text | math_block) (image | comment | text | math_block | INLINE_WHITESPACE)* INLINE_WHITESPACE?
inline_content: INLINE_WHITESPACE? (image | comment | text | math_block) (image | comment | text | math_block | INLINE_WHITESPACE)* INLINE_WHITESPACE?

// lists

list_bullet: SIMPLE_LIST_BULLET (/[^ `]/ | math_block)* | COMPOSITE_LIST_BULLET (/[^`}]/ | math_block)* "}" 
list_item: INLINE_WHITESPACE? list_bullet (INLINE_WHITESPACE inline_content)? _INLINE_WHITESPACE?

// block

block: block_title _block_structure _BLOCK_END
block_title: _BLOCK_TAG (_INLINE_WHITESPACE BLOCK_TYPE_TAG)? _BLOCK_TAG_SEPPARATOR (_INLINE_WHITESPACE title)? _INLINE_WHITESPACE?

_block_structure: (NEWLINE (_INLINE_WHITESPACE? _NEWLINE)? _block_object _INLINE_WHITESPACE?)*
_block_object: (block | list_item | table | center | content)

// center

center: INLINE_WHITESPACE? CENTER_OPEN (_INLINE_WHITESPACE | NEWLINE)* (_inline_object (INLINE_WHITESPACE | NEWLINE)*)+ CENTER_CLOSE _INLINE_WHITESPACE?

// table

table: table_row+
table_row: TABLE_DELIMITER (table_content _INLINE_WHITESPACE? TABLE_DELIMITER)+ _INLINE_WHITESPACE? _NEWLINE
         | TABLE_SEPPARATOR _NEWLINE
table_content: (comment | text | math_block | _INLINE_WHITESPACE)*

// math block

math_block: MATH_BLOCK_DELIMITER math_content MATH_BLOCK_DELIMITER

// comment

comment: COMMENT_DELIMITER COMMENT_TEXT COMMENT_DELIMITER
indented_comment: INLINE_WHITESPACE? comment

// headers

chapter_header: _CHAPTER_TAG _INLINE_WHITESPACE title _INLINE_WHITESPACE?
section_header: _SECTION_TAG _INLINE_WHITESPACE title _INLINE_WHITESPACE?
subsection_header: _SUBSECTION_TAG _INLINE_WHITESPACE title _INLINE_WHITESPACE?
subsubsection_header: _SUBSUBSECTION_TAG _INLINE_WHITESPACE title _INLINE_WHITESPACE?

// image

image: IMAGE



//////////////// MATH CONTENT ////////////////////////////////////////////////////////////////////////////////////////////////



NUMBER: /[0-9\.]+/
LETTER: /[a-zA-Z]/

PARENTHESES: "(" | ")" | "[" | "]" | /\|(?!\-)/ | "{{" | "}}"
PUNCTUATION: "," | "'" | ":" | ";" | "?" | "\""  | " /" | "/ "

SHORTCUT_OPERATOR: "<=>" | "<=" | "=>" | "|->" | "->" | "<-" | "<->" | ">>" | "<<" | "\\Σ" | "\\π" | "\\∪" | "\\∩" | "\\∫" | /\\(?![\\\]\[\)\(}{\|)])/
UNICODE_OPERATOR: /[∧∨∩∪∀∃∄∂∫≤≥<>\!\|∈∉∙≆≃≅×±¬∤⊍≋\~≡≢≈≉⊂⊆⊃⊇≠\=\+\-\*]/
KEYWORD_OPERATOR:  "limsup" | "liminf" | "arccos" | "arcsin"  | "argmax" | "argmin" | "mod" | "min" | "max" | "sin" | "cos" | "tan" | "exp" | "log" | "ln" | "sup" | "inf" | "sgn" | "lim" | "diag" | "span" |  "conv" |  "cone" 

MATH_SYMBOLS: /[∞⟨⟩⋱︙⠇∇⊥∅↾◦○￮∝¶✓≼≺⇳⇓⇑↓↑⊄⊅⋡∋⊴⊵⊲⊳⋪⋫⋬⋭∦⌈⌉⌊𝨨⌋⊊⊋]/
MATH_GREEK_SYMBOLS: /[αβγδεφηικλμν𝛝ωπΘψρστυχξζΩΨΣΔΦΓΛΞ]/
MATH_BB_SYMBOLS: /[𝔸𝔹ℂ𝔻𝔼𝔽𝔾ℍ𝕀𝕁𝕂𝕃𝕄ℕ𝕆ℙℚℝ𝕊𝕋𝕌𝕍𝕎𝕏𝕐ℤ]/
MATH_CAL_SYMBOLS: /[𝓐𝓑𝓒𝓓𝓔𝓕𝓖𝓗𝓘𝓙𝓚𝓛𝓜𝓝𝓞𝓟𝓠𝓡𝓢𝓣𝓤𝓥𝓦𝓧𝓨𝓩]/

OPEN_BRACKET: /(?<!{){(?!{)/
CLOSE_BRACKET: /(?<!})}(?!})/

OPEN_BRACKET_EXPLICIT: "{{"
CLOSE_BRACKET_EXPLICIT: "}}"

DIVISION_OPERATOR: "/"
ROOT_OPERATOR: "√"

_TEXT_BLOCK_DELIMITER: "``"
MATH_TEXT: /[^`]+/

// array

ARRAY_OPEN: /(\\[\(\[\{\\\|])/
ARRAY_CLOSE: /(\\[\)\]}\\\|])/
ARRAY_COLUMN_DIVIDER: /(?<!&)&(?!&)/
_ARRAY_ROW_DIVIDER: "&&"

// over/underline/sub/superscript

OVERLINE_OPERATOR: /\^(?=[ }`])/
UNDERLINE_OPERATOR: /_(?=[ }`])/
SUPERSCRIPT_OPERATOR: /\^(?![ }`])/
SUBSCRIPT_OPERATOR: /_(?![ }`])/



//////////////////////////////////////////////////////////////////


math_content: _INLINE_WHITESPACE? (expression | array | _structural | inline_whitespace | NEWLINE | comment)+ _INLINE_WHITESPACE?

expression: (_math_object inline_whitespace)* _math_object
sub_expression: OPEN_BRACKET _INLINE_WHITESPACE? expression _INLINE_WHITESPACE? CLOSE_BRACKET
              | symbol
          
_math_object: term | sub_super_script_term | underline_overline | fraction | root | text_block | array

// atomic

_structural: PUNCTUATION | PARENTHESES

term: (symbol | _structural)+
symbol: SHORTCUT_OPERATOR | UNICODE_OPERATOR | KEYWORD_OPERATOR | NUMBER | LETTER | MATH_GREEK_SYMBOLS | MATH_BB_SYMBOLS | MATH_CAL_SYMBOLS | MATH_SYMBOLS

text_block: _TEXT_BLOCK_DELIMITER MATH_TEXT _TEXT_BLOCK_DELIMITER

// operations

underline_overline: (OPEN_BRACKET | inline_whitespace) sub_expression (OVERLINE_OPERATOR | UNDERLINE_OPERATOR) (CLOSE_BRACKET | inline_whitespace)

sub_super_script_term: sub_expression SUBSCRIPT_OPERATOR sub_expression SUPERSCRIPT_OPERATOR sub_expression
                     | sub_expression SUPERSCRIPT_OPERATOR sub_expression SUBSCRIPT_OPERATOR sub_expression
                     | sub_expression (SUBSCRIPT_OPERATOR | SUPERSCRIPT_OPERATOR) sub_expression
                
                
fraction: sub_expression DIVISION_OPERATOR sub_expression
root: sub_expression? ROOT_OPERATOR sub_expression

// array

array: ARRAY_OPEN (_INLINE_WHITESPACE? _NEWLINE)? (array_row ((_ARRAY_ROW_DIVIDER | _NEWLINE) array_row)+) _INLINE_WHITESPACE? _NEWLINE? _INLINE_WHITESPACE? ARRAY_CLOSE
array_row: _array_item (_INLINE_WHITESPACE? ARRAY_COLUMN_DIVIDER _array_item)*
_array_item: _INLINE_WHITESPACE? (expression | comment | text_block | inline_whitespace)+ _INLINE_WHITESPACE? 
'''

# %%
sample = r'''

'''

# %%
p = Lark(grammar)

# %%
t = p.parse(sample)
# Out:
# ---------------------------------------------------------------------------
# UnexpectedCharacters                      Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 t = p.parse(sample)
#
# File /opt/homebrew/lib/python3.11/site-packages/lark/lark.py:645, in Lark.parse(self, text, start, on_error)
#     627 def parse(self, text: str, start: Optional[str]=None, on_error: 'Optional[Callable[[UnexpectedInput], bool]]'=None) -> 'ParseTree':
#     628     """Parse the given text, according to the options provided.
#     629
#     630     Parameters:
#    (...)
#     643
#     644     """
# --> 645     return self.parser.parse(text, start=start, on_error=on_error)
#
# File /opt/homebrew/lib/python3.11/site-packages/lark/parser_frontends.py:96, in ParsingFrontend.parse(self, text, start, on_error)
#      94 kw = {} if on_error is None else {'on_error': on_error}
#      95 stream = self._make_lexer_thread(text)
# ---> 96 return self.parser.parse(stream, chosen_start, **kw)
#
# File /opt/homebrew/lib/python3.11/site-packages/lark/parsers/earley.py:266, in Parser.parse(self, lexer, start)
#     263     else:
#     264         columns[0].add(item)
# --> 266 to_scan = self._parse(lexer, columns, to_scan, start_symbol)
#     268 # If the parse was successful, the start
#     269 # symbol should have been completed in the last step of the Earley cycle, and will be in
#     270 # this column. Find the item for the start_symbol, which is the root of the SPPF tree.
#     271 solutions = [n.node for n in columns[-1] if n.is_complete and n.node is not None and n.s == start_symbol and n.start == 0]
#
# File /opt/homebrew/lib/python3.11/site-packages/lark/parsers/xearley.py:146, in Parser._parse(self, stream, columns, to_scan, start_symbol)
#     143 for token in stream:
#     144     self.predict_and_complete(i, to_scan, columns, transitives)
# --> 146     to_scan = scan(i, to_scan)
#     148     if token == '\n':
#     149         text_line += 1
#
# File /opt/homebrew/lib/python3.11/site-packages/lark/parsers/xearley.py:119, in Parser._parse.<locals>.scan(i, to_scan)
#     117 if not next_set and not delayed_matches and not next_to_scan:
#     118     considered_rules = list(sorted(to_scan, key=lambda key: key.rule.origin.name))
# --> 119     raise UnexpectedCharacters(stream, i, text_line, text_column, {item.expect.name for item in to_scan},
#     120                                set(to_scan), state=frozenset(i.s for i in to_scan),
#     121                                considered_rules=considered_rules
#     122                                )
#     124 return next_to_scan
#
# UnexpectedCharacters: No terminal matches '_' in the current parser context, at line 9 col 5
#
# - `G_ = (G, ∙, ∙^{-1}, 1)` 				## G_ is G un
#     ^
# Expected one of:
# 	* ARRAY_OPEN
# 	* SUPERSCRIPT_OPERATOR
# 	* COMMENT_DELIMITER
# 	* SUBSCRIPT_OPERATOR
# 	* TRIPLE_SPACE
# 	* _TEXT_BLOCK_DELIMITER
# 	* MATH_BLOCK_DELIMITER
# 	* SPACE
# 	* PARENTHESES
# 	* MATH_BB_SYMBOLS
# 	* DIVISION_OPERATOR
# 	* SHORTCUT_OPERATOR
# 	* PUNCTUATION
# 	* DOUBLE_SPACE
# 	* MATH_GREEK_SYMBOLS
# 	* MATH_SYMBOLS
# 	* OPEN_BRACKET
# 	* NUMBER
# 	* NEWLINE
# 	* MATH_CAL_SYMBOLS
# 	* TAB
# 	* _INLINE_WHITESPACE
# 	* KEYWORD_OPERATOR
# 	* ROOT_OPERATOR
# 	* LETTER
# 	* UNICODE_OPERATOR

# %%
print(unwrap(t))
# Out:
# Tree(Token('RULE', 'start'), [
#   Tree(Token('RULE', 'chapter_header'), [
#     Tree(Token('RULE', 'title'), [
#       Token('TITLE', 'Homomorphisms')
#     ])
#   ]),
#   Token('NEWLINE', '\n'),
#   Token('NEWLINE', '\n'),
#   Tree(Token('RULE', 'section_header'), [
#     Tree(Token('RULE', 'title'), [
#       Token('TITLE', 'Group homomorphism')
#     ])
#   ]),
#   Token('NEWLINE', '\n'),
#   Token('NEWLINE', '\n'),
#   Token('NEWLINE', '\n'),
#   Tree(Token('RULE', 'block'), [
#     Tree(Token('RULE', 'block_title'), [
#       Token('BLOCK_TYPE_TAG', 'Df'),
#       Tree(Token('RULE', 'title'), [
#         Token('TITLE', 'Group homomorphism')
#       ])
#     ]),
#     Token('NEWLINE', '\n'),
#     Tree(Token('RULE', 'list_item'), [
#       Tree(Token('RULE', 'list_bullet'), [
#         Token('SIMPLE_LIST_BULLET', '-')
#       ]),
#       Token('INLINE_WHITESPACE', ' '),
#       Tree(Token('RULE', 'inline_content'), [
#         Tree(Token('RULE', 'math_block'), [
#           Token('MATH_BLOCK_DELIMITER', '`'),
#           Tree(Token('RULE', 'math_content'), [
#             Tree(Token('RULE', 'expression'), [
#               Tree(Token('RULE', 'underline_overline'), [
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Tree(Token('RULE', 'term'), [
#                     Tree(Token('RULE', 'symbol'), [
#                       Token('LETTER', 'G')
#                     ])
#                   ])
#                 ]),
#                 Token('UNDERLINE_OPERATOR', '_')
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'operator'), [
#                   Token('UNICODE_OPERATOR', '=')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Token('PARENTHESES', '('),
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('LETTER', 'G')
#                 ]),
#                 Token('PUNCTUATION', ',')
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'operator'), [
#                   Token('UNICODE_OPERATOR', '∙')
#                 ]),
#                 Token('PUNCTUATION', ',')
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'sub_super_script_term'), [
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Tree(Token('RULE', 'term'), [
#                     Tree(Token('RULE', 'operator'), [
#                       Token('UNICODE_OPERATOR', '∙')
#                     ])
#                   ])
#                 ]),
#                 Token('SUPERSCRIPT_OPERATOR', '^'),
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Token('OPEN_BRACKET', '{'),
#                   Tree(Token('RULE', 'expression'), [
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'operator'), [
#                         Token('UNICODE_OPERATOR', '-')
#                       ]),
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('NUMBER', '1')
#                       ])
#                     ])
#                   ]),
#                   Token('CLOSE_BRACKET', '}')
#                 ])
#               ])
#             ]),
#             Tree(Token('RULE', 'expression'), [
#               Tree(Token('RULE', 'term'), [
#                 Token('PUNCTUATION', ',')
#               ])
#             ]),
#             Tree(Token('RULE', 'inline_whitespace'), [
#               Token('SPACE', ' ')
#             ]),
#             Tree(Token('RULE', 'expression'), [
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('NUMBER', '1')
#                 ]),
#                 Token('PARENTHESES', ')')
#               ])
#             ])
#           ]),
#           Token('MATH_BLOCK_DELIMITER', '`')
#         ]),
#         Token('INLINE_WHITESPACE', ' \t\t\t\t'),
#         Tree(Token('RULE', 'comment'), [
#           Token('COMMENT_DELIMITER', '##'),
#           Token('COMMENT_TEXT', ' G_ is G underlined '),
#           Token('COMMENT_DELIMITER', '##')
#         ])
#       ])
#     ]),
#     Token('NEWLINE', '\n'),
#     Tree(Token('RULE', 'list_item'), [
#       Tree(Token('RULE', 'list_bullet'), [
#         Token('SIMPLE_LIST_BULLET', '-')
#       ]),
#       Token('INLINE_WHITESPACE', ' '),
#       Tree(Token('RULE', 'inline_content'), [
#         Tree(Token('RULE', 'math_block'), [
#           Token('MATH_BLOCK_DELIMITER', '`'),
#           Tree(Token('RULE', 'math_content'), [
#             Tree(Token('RULE', 'expression'), [
#               Tree(Token('RULE', 'underline_overline'), [
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Tree(Token('RULE', 'term'), [
#                     Tree(Token('RULE', 'symbol'), [
#                       Token('LETTER', 'H')
#                     ])
#                   ])
#                 ]),
#                 Token('UNDERLINE_OPERATOR', '_')
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'operator'), [
#                   Token('UNICODE_OPERATOR', '=')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Token('PARENTHESES', '('),
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('LETTER', 'H')
#                 ]),
#                 Token('PUNCTUATION', ',')
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'operator'), [
#                   Token('UNICODE_OPERATOR', '*')
#                 ]),
#                 Token('PUNCTUATION', ',')
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Token('PUNCTUATION', "'"),
#                 Token('PUNCTUATION', ',')
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('LETTER', 'e')
#                 ]),
#                 Token('PARENTHESES', ')')
#               ])
#             ])
#           ]),
#           Token('MATH_BLOCK_DELIMITER', '`')
#         ])
#       ])
#     ]),
#     Token('NEWLINE', '\n'),
#     Tree(Token('RULE', 'list_item'), [
#       Tree(Token('RULE', 'list_bullet'), [
#         Token('SIMPLE_LIST_BULLET', '-')
#       ]),
#       Token('INLINE_WHITESPACE', ' '),
#       Tree(Token('RULE', 'inline_content'), [
#         Tree(Token('RULE', 'text'), [
#           Token('WORD', 'Homomorphism')
#         ]),
#         Tree(Token('RULE', 'text'), [
#           Token('INLINE_WHITESPACE', ' '),
#           Token('WORD', 'is')
#         ]),
#         Token('INLINE_WHITESPACE', ' '),
#         Tree(Token('RULE', 'math_block'), [
#           Token('MATH_BLOCK_DELIMITER', '`'),
#           Tree(Token('RULE', 'math_content'), [
#             Tree(Token('RULE', 'expression'), [
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('MATH_GREEK_SYMBOLS', 'φ')
#                 ]),
#                 Token('PUNCTUATION', ':'),
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('LETTER', 'G')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'operator'), [
#                   Token('SHORTCUT_OPERATOR', '->')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('LETTER', 'H')
#                 ]),
#                 Token('PUNCTUATION', ':')
#               ])
#             ])
#           ]),
#           Token('MATH_BLOCK_DELIMITER', '`')
#         ])
#       ])
#     ]),
#     Token('NEWLINE', '\n'),
#     Tree(Token('RULE', 'list_item'), [
#       Token('INLINE_WHITESPACE', '\t'),
#       Tree(Token('RULE', 'list_bullet'), [
#         Token('SIMPLE_LIST_BULLET', '-'),
#         Token('__ANON_0', '1'),
#         Token('__ANON_0', '.')
#       ]),
#       Token('INLINE_WHITESPACE', ' '),
#       Tree(Token('RULE', 'inline_content'), [
#         Tree(Token('RULE', 'math_block'), [
#           Token('MATH_BLOCK_DELIMITER', '`'),
#           Tree(Token('RULE', 'math_content'), [
#             Tree(Token('RULE', 'expression'), [
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('MATH_GREEK_SYMBOLS', 'φ')
#                 ]),
#                 Token('PARENTHESES', '('),
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('LETTER', 'a')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'operator'), [
#                   Token('UNICODE_OPERATOR', '∙')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('LETTER', 'b')
#                 ]),
#                 Token('PARENTHESES', ')')
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'operator'), [
#                   Token('UNICODE_OPERATOR', '=')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('MATH_GREEK_SYMBOLS', 'φ')
#                 ]),
#                 Token('PARENTHESES', '('),
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('LETTER', 'a')
#                 ]),
#                 Token('PARENTHESES', ')')
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'operator'), [
#                   Token('UNICODE_OPERATOR', '*')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('MATH_GREEK_SYMBOLS', 'φ')
#                 ]),
#                 Token('PARENTHESES', '('),
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('LETTER', 'b')
#                 ]),
#                 Token('PARENTHESES', ')')
#               ])
#             ])
#           ]),
#           Token('MATH_BLOCK_DELIMITER', '`')
#         ])
#       ])
#     ]),
#     Token('NEWLINE', '\n'),
#     Tree(Token('RULE', 'list_item'), [
#       Token('INLINE_WHITESPACE', '\t'),
#       Tree(Token('RULE', 'list_bullet'), [
#         Token('SIMPLE_LIST_BULLET', '-'),
#         Token('__ANON_0', '2'),
#         Token('__ANON_0', '.')
#       ]),
#       Token('INLINE_WHITESPACE', ' '),
#       Tree(Token('RULE', 'inline_content'), [
#         Tree(Token('RULE', 'math_block'), [
#           Token('MATH_BLOCK_DELIMITER', '`'),
#           Tree(Token('RULE', 'math_content'), [
#             Tree(Token('RULE', 'expression'), [
#               Tree(Token('RULE', 'sub_super_script_term'), [
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Tree(Token('RULE', 'term'), [
#                     Tree(Token('RULE', 'symbol'), [
#                       Token('MATH_GREEK_SYMBOLS', 'φ')
#                     ]),
#                     Token('PARENTHESES', '('),
#                     Tree(Token('RULE', 'symbol'), [
#                       Token('LETTER', 'a')
#                     ])
#                   ])
#                 ]),
#                 Token('SUPERSCRIPT_OPERATOR', '^'),
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Token('OPEN_BRACKET', '{'),
#                   Tree(Token('RULE', 'expression'), [
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'operator'), [
#                         Token('UNICODE_OPERATOR', '-')
#                       ]),
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('NUMBER', '1')
#                       ])
#                     ])
#                   ]),
#                   Token('CLOSE_BRACKET', '}')
#                 ])
#               ])
#             ]),
#             Tree(Token('RULE', 'expression'), [
#               Tree(Token('RULE', 'term'), [
#                 Token('PARENTHESES', ')')
#               ])
#             ]),
#             Tree(Token('RULE', 'inline_whitespace'), [
#               Token('SPACE', ' ')
#             ]),
#             Tree(Token('RULE', 'expression'), [
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'operator'), [
#                   Token('UNICODE_OPERATOR', '=')
#                 ])
#               ])
#             ]),
#             Tree(Token('RULE', 'inline_whitespace'), [
#               Token('SPACE', ' ')
#             ]),
#             Tree(Token('RULE', 'expression'), [
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('MATH_GREEK_SYMBOLS', 'φ')
#                 ]),
#                 Token('PARENTHESES', '('),
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('LETTER', 'a')
#                 ]),
#                 Token('PARENTHESES', ')'),
#                 Token('PUNCTUATION', "'")
#               ])
#             ])
#           ]),
#           Token('MATH_BLOCK_DELIMITER', '`')
#         ])
#       ])
#     ]),
#     Token('NEWLINE', '\n'),
#     Tree(Token('RULE', 'list_item'), [
#       Token('INLINE_WHITESPACE', '\t'),
#       Tree(Token('RULE', 'list_bullet'), [
#         Token('SIMPLE_LIST_BULLET', '-'),
#         Token('__ANON_0', '3'),
#         Token('__ANON_0', '.')
#       ]),
#       Token('INLINE_WHITESPACE', ' '),
#       Tree(Token('RULE', 'inline_content'), [
#         Tree(Token('RULE', 'math_block'), [
#           Token('MATH_BLOCK_DELIMITER', '`'),
#           Tree(Token('RULE', 'math_content'), [
#             Tree(Token('RULE', 'expression'), [
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('MATH_GREEK_SYMBOLS', 'φ')
#                 ]),
#                 Token('PARENTHESES', '('),
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('NUMBER', '1')
#                 ]),
#                 Token('PARENTHESES', ')')
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'operator'), [
#                   Token('UNICODE_OPERATOR', '=')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('LETTER', 'e')
#                 ])
#               ])
#             ])
#           ]),
#           Token('MATH_BLOCK_DELIMITER', '`')
#         ])
#       ])
#     ]),
#     Token('NEWLINE', '\n'),
#     Tree(Token('RULE', 'list_item'), [
#       Tree(Token('RULE', 'list_bullet'), [
#         Token('SIMPLE_LIST_BULLET', '-')
#       ]),
#       Token('INLINE_WHITESPACE', ' '),
#       Tree(Token('RULE', 'inline_content'), [
#         Tree(Token('RULE', 'math_block'), [
#           Token('MATH_BLOCK_DELIMITER', '`'),
#           Tree(Token('RULE', 'math_content'), [
#             Tree(Token('RULE', 'expression'), [
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('MATH_GREEK_SYMBOLS', 'φ')
#                 ]),
#                 Token('PUNCTUATION', ':')
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'underline_overline'), [
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Tree(Token('RULE', 'term'), [
#                     Tree(Token('RULE', 'symbol'), [
#                       Token('LETTER', 'G')
#                     ])
#                   ])
#                 ]),
#                 Token('UNDERLINE_OPERATOR', '_')
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'operator'), [
#                   Token('SHORTCUT_OPERATOR', '->')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'underline_overline'), [
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Tree(Token('RULE', 'term'), [
#                     Tree(Token('RULE', 'symbol'), [
#                       Token('LETTER', 'H')
#                     ])
#                   ])
#                 ]),
#                 Token('UNDERLINE_OPERATOR', '_')
#               ])
#             ])
#           ]),
#           Token('MATH_BLOCK_DELIMITER', '`')
#         ]),
#         Tree(Token('RULE', 'text'), [
#           Token('INLINE_WHITESPACE', ' '),
#           Token('WORD', 'is'),
#           Token('INLINE_WHITESPACE', ' '),
#           Token('WORD', 'shorthand')
#         ])
#       ])
#     ])
#   ]),
#   Token('NEWLINE', '\n'),
#   Token('NEWLINE', '\n'),
#   Tree(Token('RULE', 'block'), [
#     Tree(Token('RULE', 'block_title'), [
#       Token('BLOCK_TYPE_TAG', 'Ob'),
#       Tree(Token('RULE', 'title'), [
#         Token('TITLE', 'First condition (1.1)')
#       ])
#     ]),
#     Token('NEWLINE', '\n'),
#     Tree(Token('RULE', 'center'), [
#       Token('CENTER_OPEN', '>'),
#       Tree(Token('RULE', 'inline_content'), [
#         Tree(Token('RULE', 'math_block'), [
#           Token('MATH_BLOCK_DELIMITER', '`'),
#           Tree(Token('RULE', 'math_content'), [
#             Tree(Token('RULE', 'expression'), [
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('MATH_GREEK_SYMBOLS', 'φ')
#                 ])
#               ])
#             ])
#           ]),
#           Token('MATH_BLOCK_DELIMITER', '`')
#         ]),
#         Tree(Token('RULE', 'text'), [
#           Token('INLINE_WHITESPACE', ' '),
#           Token('WORD', 'is'),
#           Token('INLINE_WHITESPACE', ' '),
#           Token('WORD', 'a'),
#           Token('INLINE_WHITESPACE', ' '),
#           Token('WORD', 'homemorphism')
#         ]),
#         Token('INLINE_WHITESPACE', ' '),
#         Tree(Token('RULE', 'math_block'), [
#           Token('MATH_BLOCK_DELIMITER', '`'),
#           Tree(Token('RULE', 'math_content'), [
#             Tree(Token('RULE', 'expression'), [
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'operator'), [
#                   Token('SHORTCUT_OPERATOR', '<=>')
#                 ])
#               ])
#             ])
#           ]),
#           Token('MATH_BLOCK_DELIMITER', '`')
#         ]),
#         Token('INLINE_WHITESPACE', ' '),
#         Tree(Token('RULE', 'text'), [
#           Token('WORD', '1.')
#         ]),
#         Tree(Token('RULE', 'text'), [
#           Token('INLINE_WHITESPACE', ' '),
#           Token('WORD', 'holds')
#         ])
#       ]),
#       Token('INLINE_WHITESPACE', ' '),
#       Token('CENTER_CLOSE', '<')
#     ]),
#     Token('NEWLINE', '\n'),
#     Tree(Token('RULE', 'block'), [
#       Tree(Token('RULE', 'block_title'), [
#         Token('BLOCK_TYPE_TAG', 'Proof')
#       ]),
#       Token('NEWLINE', '\n'),
#       Tree(Token('RULE', 'list_item'), [
#         Tree(Token('RULE', 'list_bullet'), [
#           Token('SIMPLE_LIST_BULLET', '-'),
#           Token('__ANON_0', '3'),
#           Token('__ANON_0', '.')
#         ]),
#         Token('INLINE_WHITESPACE', ' '),
#         Tree(Token('RULE', 'inline_content'), [
#           Tree(Token('RULE', 'math_block'), [
#             Token('MATH_BLOCK_DELIMITER', '`'),
#             Tree(Token('RULE', 'math_content'), [
#               Tree(Token('RULE', 'expression'), [
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('LETTER', 'e')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'operator'), [
#                     Token('UNICODE_OPERATOR', '*')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('MATH_GREEK_SYMBOLS', 'φ')
#                   ]),
#                   Token('PARENTHESES', '('),
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('NUMBER', '1')
#                   ]),
#                   Token('PARENTHESES', ')')
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'operator'), [
#                     Token('UNICODE_OPERATOR', '=')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('MATH_GREEK_SYMBOLS', 'φ')
#                   ]),
#                   Token('PARENTHESES', '('),
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('NUMBER', '1')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'operator'), [
#                     Token('UNICODE_OPERATOR', '∙')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('NUMBER', '1')
#                   ]),
#                   Token('PARENTHESES', ')')
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'operator'), [
#                     Token('UNICODE_OPERATOR', '=')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('MATH_GREEK_SYMBOLS', 'φ')
#                   ]),
#                   Token('PARENTHESES', '('),
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('NUMBER', '1')
#                   ]),
#                   Token('PARENTHESES', ')')
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'operator'), [
#                     Token('UNICODE_OPERATOR', '*')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('MATH_GREEK_SYMBOLS', 'φ')
#                   ]),
#                   Token('PARENTHESES', '('),
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('NUMBER', '1')
#                   ]),
#                   Token('PARENTHESES', ')')
#                 ])
#               ])
#             ]),
#             Token('MATH_BLOCK_DELIMITER', '`')
#           ])
#         ])
#       ]),
#       Token('NEWLINE', '\n'),
#       Tree(Token('RULE', 'list_item'), [
#         Tree(Token('RULE', 'list_bullet'), [
#           Token('SIMPLE_LIST_BULLET', '-'),
#           Token('__ANON_0', '2'),
#           Token('__ANON_0', '.')
#         ])
#       ]),
#       Token('NEWLINE', '\n'),
#       Tree(Token('RULE', 'list_item'), [
#         Token('INLINE_WHITESPACE', '\t'),
#         Tree(Token('RULE', 'list_bullet'), [
#           Token('SIMPLE_LIST_BULLET', '-')
#         ]),
#         Token('INLINE_WHITESPACE', ' '),
#         Tree(Token('RULE', 'inline_content'), [
#           Tree(Token('RULE', 'math_block'), [
#             Token('MATH_BLOCK_DELIMITER', '`'),
#             Tree(Token('RULE', 'math_content'), [
#               Tree(Token('RULE', 'expression'), [
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('LETTER', 'e')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'operator'), [
#                     Token('UNICODE_OPERATOR', '=')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('MATH_GREEK_SYMBOLS', 'φ')
#                   ]),
#                   Token('PARENTHESES', '('),
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('NUMBER', '1')
#                   ]),
#                   Token('PARENTHESES', ')')
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'operator'), [
#                     Token('UNICODE_OPERATOR', '=')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('MATH_GREEK_SYMBOLS', 'φ')
#                   ]),
#                   Token('PARENTHESES', '('),
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('LETTER', 'a')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'operator'), [
#                     Token('UNICODE_OPERATOR', '∙')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'sub_super_script_term'), [
#                   Tree(Token('RULE', 'sub_expression'), [
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('LETTER', 'a')
#                       ])
#                     ])
#                   ]),
#                   Token('SUPERSCRIPT_OPERATOR', '^'),
#                   Tree(Token('RULE', 'sub_expression'), [
#                     Token('OPEN_BRACKET', '{'),
#                     Tree(Token('RULE', 'expression'), [
#                       Tree(Token('RULE', 'term'), [
#                         Tree(Token('RULE', 'operator'), [
#                           Token('UNICODE_OPERATOR', '-')
#                         ]),
#                         Tree(Token('RULE', 'symbol'), [
#                           Token('NUMBER', '1')
#                         ])
#                       ])
#                     ]),
#                     Token('CLOSE_BRACKET', '}')
#                   ])
#                 ])
#               ]),
#               Tree(Token('RULE', 'expression'), [
#                 Tree(Token('RULE', 'term'), [
#                   Token('PARENTHESES', ')')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'expression'), [
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'operator'), [
#                     Token('UNICODE_OPERATOR', '=')
#                   ])
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'expression'), [
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('MATH_GREEK_SYMBOLS', 'φ')
#                   ])
#                 ])
#               ]),
#               Tree(Token('RULE', 'expression'), [
#                 Tree(Token('RULE', 'term'), [
#                   Token('PARENTHESES', '('),
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('LETTER', 'a')
#                   ]),
#                   Token('PARENTHESES', ')'),
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('MATH_GREEK_SYMBOLS', 'φ')
#                   ]),
#                   Token('PARENTHESES', '(')
#                 ])
#               ]),
#               Tree(Token('RULE', 'expression'), [
#                 Tree(Token('RULE', 'sub_super_script_term'), [
#                   Tree(Token('RULE', 'sub_expression'), [
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('LETTER', 'a')
#                       ])
#                     ])
#                   ]),
#                   Token('SUPERSCRIPT_OPERATOR', '^'),
#                   Tree(Token('RULE', 'sub_expression'), [
#                     Token('OPEN_BRACKET', '{'),
#                     Tree(Token('RULE', 'expression'), [
#                       Tree(Token('RULE', 'term'), [
#                         Tree(Token('RULE', 'operator'), [
#                           Token('UNICODE_OPERATOR', '-')
#                         ]),
#                         Tree(Token('RULE', 'symbol'), [
#                           Token('NUMBER', '1')
#                         ])
#                       ])
#                     ]),
#                     Token('CLOSE_BRACKET', '}')
#                   ])
#                 ])
#               ]),
#               Tree(Token('RULE', 'expression'), [
#                 Tree(Token('RULE', 'term'), [
#                   Token('PARENTHESES', ')')
#                 ])
#               ])
#             ]),
#             Token('MATH_BLOCK_DELIMITER', '`')
#           ])
#         ])
#       ]),
#       Token('NEWLINE', '\n'),
#       Tree(Token('RULE', 'list_item'), [
#         Token('INLINE_WHITESPACE', '\t'),
#         Tree(Token('RULE', 'list_bullet'), [
#           Token('SIMPLE_LIST_BULLET', '-')
#         ]),
#         Token('INLINE_WHITESPACE', ' '),
#         Tree(Token('RULE', 'inline_content'), [
#           Tree(Token('RULE', 'text'), [
#             Token('WORD', 'By'),
#             Token('INLINE_WHITESPACE', ' '),
#             Token('WORD', 'uniqueness'),
#             Token('INLINE_WHITESPACE', ' '),
#             Token('WORD', 'of'),
#             Token('INLINE_WHITESPACE', ' '),
#             Token('WORD', 'inverse'),
#             Token('INLINE_WHITESPACE', ' '),
#             Token('WORD', 'elements')
#           ]),
#           Token('INLINE_WHITESPACE', ' '),
#           Tree(Token('RULE', 'math_block'), [
#             Token('MATH_BLOCK_DELIMITER', '`'),
#             Tree(Token('RULE', 'math_content'), [
#               Tree(Token('RULE', 'expression'), [
#                 Tree(Token('RULE', 'sub_super_script_term'), [
#                   Tree(Token('RULE', 'sub_expression'), [
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('MATH_GREEK_SYMBOLS', 'φ')
#                       ]),
#                       Token('PARENTHESES', '('),
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('LETTER', 'a')
#                       ]),
#                       Token('PARENTHESES', ')')
#                     ])
#                   ]),
#                   Token('SUPERSCRIPT_OPERATOR', '^'),
#                   Tree(Token('RULE', 'sub_expression'), [
#                     Token('OPEN_BRACKET', '{'),
#                     Tree(Token('RULE', 'expression'), [
#                       Tree(Token('RULE', 'term'), [
#                         Tree(Token('RULE', 'operator'), [
#                           Token('UNICODE_OPERATOR', '-')
#                         ]),
#                         Tree(Token('RULE', 'symbol'), [
#                           Token('NUMBER', '1')
#                         ])
#                       ])
#                     ]),
#                     Token('CLOSE_BRACKET', '}')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'operator'), [
#                     Token('UNICODE_OPERATOR', '=')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'sub_super_script_term'), [
#                   Tree(Token('RULE', 'sub_expression'), [
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('MATH_GREEK_SYMBOLS', 'φ')
#                       ]),
#                       Token('PARENTHESES', '('),
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('LETTER', 'a')
#                       ])
#                     ])
#                   ]),
#                   Token('SUPERSCRIPT_OPERATOR', '^'),
#                   Tree(Token('RULE', 'sub_expression'), [
#                     Token('OPEN_BRACKET', '{'),
#                     Tree(Token('RULE', 'expression'), [
#                       Tree(Token('RULE', 'term'), [
#                         Tree(Token('RULE', 'operator'), [
#                           Token('UNICODE_OPERATOR', '-')
#                         ]),
#                         Tree(Token('RULE', 'symbol'), [
#                           Token('NUMBER', '1')
#                         ])
#                       ])
#                     ]),
#                     Token('CLOSE_BRACKET', '}')
#                   ])
#                 ])
#               ]),
#               Tree(Token('RULE', 'expression'), [
#                 Tree(Token('RULE', 'term'), [
#                   Token('PARENTHESES', ')')
#                 ])
#               ])
#             ]),
#             Token('MATH_BLOCK_DELIMITER', '`')
#           ]),
#           Tree(Token('RULE', 'text'), [
#             Token('WORD', '.')
#           ])
#         ])
#       ])
#     ])
#   ]),
#   Token('NEWLINE', '\n'),
#   Token('NEWLINE', '\n'),
#   Tree(Token('RULE', 'block'), [
#     Tree(Token('RULE', 'block_title'), [
#       Token('BLOCK_TYPE_TAG', 'Ex'),
#       Tree(Token('RULE', 'title'), [
#         Token('TITLE', 'Group homomorphism')
#       ])
#     ]),
#     Token('NEWLINE', '\n'),
#     Tree(Token('RULE', 'list_item'), [
#       Tree(Token('RULE', 'list_bullet'), [
#         Token('SIMPLE_LIST_BULLET', '-')
#       ]),
#       Token('INLINE_WHITESPACE', ' '),
#       Tree(Token('RULE', 'inline_content'), [
#         Tree(Token('RULE', 'math_block'), [
#           Token('MATH_BLOCK_DELIMITER', '`'),
#           Tree(Token('RULE', 'math_content'), [
#             Tree(Token('RULE', 'expression'), [
#               Tree(Token('RULE', 'sub_super_script_term'), [
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Tree(Token('RULE', 'term'), [
#                     Tree(Token('RULE', 'symbol'), [
#                       Token('MATH_BB_SYMBOLS', 'ℂ')
#                     ])
#                   ])
#                 ]),
#                 Token('SUPERSCRIPT_OPERATOR', '^'),
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Tree(Token('RULE', 'term'), [
#                     Tree(Token('RULE', 'operator'), [
#                       Token('UNICODE_OPERATOR', '*')
#                     ])
#                   ])
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'operator'), [
#                   Token('UNICODE_OPERATOR', '=')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Token('PARENTHESES', '('),
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('LETTER', 'C')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'operator'), [
#                   Token('SHORTCUT_OPERATOR', '\\')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Token('PARENTHESES', '{{'),
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('NUMBER', '0')
#                 ]),
#                 Token('PARENTHESES', '}}'),
#                 Token('PUNCTUATION', ',')
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'operator'), [
#                   Token('UNICODE_OPERATOR', '∙')
#                 ]),
#                 Token('PUNCTUATION', ',')
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'sub_super_script_term'), [
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Tree(Token('RULE', 'term'), [
#                     Tree(Token('RULE', 'operator'), [
#                       Token('UNICODE_OPERATOR', '∙')
#                     ])
#                   ])
#                 ]),
#                 Token('SUPERSCRIPT_OPERATOR', '^'),
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Token('OPEN_BRACKET', '{'),
#                   Tree(Token('RULE', 'expression'), [
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'operator'), [
#                         Token('UNICODE_OPERATOR', '-')
#                       ]),
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('NUMBER', '1')
#                       ])
#                     ])
#                   ]),
#                   Token('CLOSE_BRACKET', '}')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Token('PUNCTUATION', ',')
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('NUMBER', '1')
#                 ]),
#                 Token('PARENTHESES', ')')
#               ])
#             ])
#           ]),
#           Token('MATH_BLOCK_DELIMITER', '`')
#         ])
#       ])
#     ]),
#     Token('NEWLINE', '\n'),
#     Tree(Token('RULE', 'list_item'), [
#       Tree(Token('RULE', 'list_bullet'), [
#         Token('SIMPLE_LIST_BULLET', '-')
#       ]),
#       Token('INLINE_WHITESPACE', ' '),
#       Tree(Token('RULE', 'inline_content'), [
#         Tree(Token('RULE', 'math_block'), [
#           Token('MATH_BLOCK_DELIMITER', '`'),
#           Tree(Token('RULE', 'math_content'), [
#             Tree(Token('RULE', 'expression'), [
#               Tree(Token('RULE', 'sub_super_script_term'), [
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Tree(Token('RULE', 'term'), [
#                     Tree(Token('RULE', 'symbol'), [
#                       Token('MATH_BB_SYMBOLS', 'ℝ')
#                     ])
#                   ])
#                 ]),
#                 Token('SUPERSCRIPT_OPERATOR', '^'),
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Tree(Token('RULE', 'term'), [
#                     Tree(Token('RULE', 'operator'), [
#                       Token('UNICODE_OPERATOR', '*')
#                     ])
#                   ])
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'operator'), [
#                   Token('UNICODE_OPERATOR', '=')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Token('PARENTHESES', '('),
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('MATH_BB_SYMBOLS', 'ℝ')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'operator'), [
#                   Token('SHORTCUT_OPERATOR', '\\')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Token('PARENTHESES', '{{'),
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('NUMBER', '0')
#                 ]),
#                 Token('PARENTHESES', '}}'),
#                 Token('PUNCTUATION', ',')
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'operator'), [
#                   Token('UNICODE_OPERATOR', '∙')
#                 ]),
#                 Token('PUNCTUATION', ',')
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'sub_super_script_term'), [
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Tree(Token('RULE', 'term'), [
#                     Tree(Token('RULE', 'operator'), [
#                       Token('UNICODE_OPERATOR', '∙')
#                     ])
#                   ])
#                 ]),
#                 Token('SUPERSCRIPT_OPERATOR', '^'),
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Token('OPEN_BRACKET', '{'),
#                   Tree(Token('RULE', 'expression'), [
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'operator'), [
#                         Token('UNICODE_OPERATOR', '-')
#                       ]),
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('NUMBER', '1')
#                       ])
#                     ])
#                   ]),
#                   Token('CLOSE_BRACKET', '}')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Token('PUNCTUATION', ',')
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'symbol'), [
#                   Token('NUMBER', '1')
#                 ]),
#                 Token('PARENTHESES', ')')
#               ])
#             ])
#           ]),
#           Token('MATH_BLOCK_DELIMITER', '`')
#         ])
#       ])
#     ]),
#     Token('NEWLINE', '\n'),
#     Tree(Token('RULE', 'list_item'), [
#       Tree(Token('RULE', 'list_bullet'), [
#         Token('SIMPLE_LIST_BULLET', '-')
#       ]),
#       Token('INLINE_WHITESPACE', ' '),
#       Tree(Token('RULE', 'inline_content'), [
#         Tree(Token('RULE', 'math_block'), [
#           Token('MATH_BLOCK_DELIMITER', '`'),
#           Tree(Token('RULE', 'math_content'), [
#             Tree(Token('RULE', 'expression'), [
#               Tree(Token('RULE', 'sub_super_script_term'), [
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Tree(Token('RULE', 'term'), [
#                     Tree(Token('RULE', 'symbol'), [
#                       Token('MATH_GREEK_SYMBOLS', 'φ')
#                     ]),
#                     Token('PUNCTUATION', ':'),
#                     Tree(Token('RULE', 'symbol'), [
#                       Token('MATH_BB_SYMBOLS', 'ℂ')
#                     ])
#                   ])
#                 ]),
#                 Token('SUPERSCRIPT_OPERATOR', '^'),
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Tree(Token('RULE', 'term'), [
#                     Tree(Token('RULE', 'operator'), [
#                       Token('UNICODE_OPERATOR', '*')
#                     ])
#                   ])
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'term'), [
#                 Tree(Token('RULE', 'operator'), [
#                   Token('SHORTCUT_OPERATOR', '->')
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
#                 Token('SPACE', ' ')
#               ]),
#               Tree(Token('RULE', 'sub_super_script_term'), [
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Tree(Token('RULE', 'term'), [
#                     Tree(Token('RULE', 'symbol'), [
#                       Token('MATH_BB_SYMBOLS', 'ℝ')
#                     ])
#                   ])
#                 ]),
#                 Token('SUPERSCRIPT_OPERATOR', '^'),
#                 Tree(Token('RULE', 'sub_expression'), [
#                   Tree(Token('RULE', 'term'), [
#                     Tree(Token('RULE', 'operator'), [
#                       Token('UNICODE_OPERATOR', '*')
#                     ])
#                   ])
#                 ])
#               ]),
#               Tree(Token('RULE', 'inline_whitespace'), [
# ...
#                     Tree(Token('RULE', 'inline_whitespace'), [
#                       Token('SPACE', ' ')
#                     ]),
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('MATH_BB_SYMBOLS', 'ℤ')
#                       ])
#                     ])
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'array_row'), [
#                   Tree(Token('RULE', 'expression'), [
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('LETTER', 'o')
#                       ]),
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('LETTER', 'r')
#                       ]),
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('LETTER', 'd')
#                       ]),
#                       Token('PARENTHESES', '('),
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('LETTER', 'G')
#                       ]),
#                       Token('PARENTHESES', ')')
#                     ]),
#                     Tree(Token('RULE', 'inline_whitespace'), [
#                       Token('SPACE', ' ')
#                     ]),
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'operator'), [
#                         Token('UNICODE_OPERATOR', '=')
#                       ])
#                     ]),
#                     Tree(Token('RULE', 'inline_whitespace'), [
#                       Token('SPACE', ' ')
#                     ]),
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('LETTER', 'k')
#                       ])
#                     ]),
#                     Tree(Token('RULE', 'inline_whitespace'), [
#                       Token('SPACE', ' ')
#                     ]),
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'operator'), [
#                         Token('UNICODE_OPERATOR', '∈')
#                       ])
#                     ]),
#                     Tree(Token('RULE', 'inline_whitespace'), [
#                       Token('SPACE', ' ')
#                     ]),
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('MATH_BB_SYMBOLS', 'ℤ')
#                       ])
#                     ])
#                   ]),
#                   Token('ARRAY_COLUMN_DIVIDER', '&'),
#                   Tree(Token('RULE', 'expression'), [
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('LETTER', 'G')
#                       ])
#                     ]),
#                     Tree(Token('RULE', 'inline_whitespace'), [
#                       Token('SPACE', ' ')
#                     ]),
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'operator'), [
#                         Token('UNICODE_OPERATOR', '≃')
#                       ])
#                     ]),
#                     Tree(Token('RULE', 'inline_whitespace'), [
#                       Token('SPACE', ' ')
#                     ]),
#                     Tree(Token('RULE', 'sub_super_script_term'), [
#                       Tree(Token('RULE', 'sub_expression'), [
#                         Tree(Token('RULE', 'term'), [
#                           Tree(Token('RULE', 'symbol'), [
#                             Token('MATH_BB_SYMBOLS', 'ℤ')
#                           ])
#                         ])
#                       ]),
#                       Token('SUBSCRIPT_OPERATOR', '_'),
#                       Tree(Token('RULE', 'sub_expression'), [
#                         Tree(Token('RULE', 'term'), [
#                           Tree(Token('RULE', 'symbol'), [
#                             Token('LETTER', 'n')
#                           ])
#                         ])
#                       ])
#                     ])
#                   ])
#                 ]),
#                 Token('ARRAY_CLOSE', '\\\\')
#               ])
#             ])
#           ]),
#           Token('MATH_BLOCK_DELIMITER', '`')
#         ])
#       ])
#     ]),
#     Token('NEWLINE', '\n'),
#     Tree(Token('RULE', 'block'), [
#       Tree(Token('RULE', 'block_title'), [
#         Token('BLOCK_TYPE_TAG', 'Proof')
#       ]),
#       Token('NEWLINE', '\n'),
#       Tree(Token('RULE', 'list_item'), [
#         Tree(Token('RULE', 'list_bullet'), [
#           Token('SIMPLE_LIST_BULLET', '-')
#         ]),
#         Token('INLINE_WHITESPACE', ' '),
#         Tree(Token('RULE', 'inline_content'), [
#           Tree(Token('RULE', 'text'), [
#             Token('WORD', 'Idea')
#           ]),
#           Tree(Token('RULE', 'text'), [
#             Token('INLINE_WHITESPACE', ' '),
#             Token('WORD', 'only')
#           ])
#         ])
#       ]),
#       Token('NEWLINE', '\n'),
#       Tree(Token('RULE', 'list_item'), [
#         Tree(Token('RULE', 'list_bullet'), [
#           Token('SIMPLE_LIST_BULLET', '-'),
#           Token('__ANON_0', '1'),
#           Token('__ANON_0', '.')
#         ]),
#         Token('INLINE_WHITESPACE', ' '),
#         Tree(Token('RULE', 'inline_content'), [
#           Tree(Token('RULE', 'math_block'), [
#             Token('MATH_BLOCK_DELIMITER', '`'),
#             Tree(Token('RULE', 'math_content'), [
#               Tree(Token('RULE', 'expression'), [
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('LETTER', 'G')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'operator'), [
#                     Token('UNICODE_OPERATOR', '=')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('MATH_SYMBOLS', '⟨')
#                   ]),
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('LETTER', 'a')
#                   ]),
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('MATH_SYMBOLS', '⟩')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('DOUBLE_SPACE', '  ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'operator'), [
#                     Token('SHORTCUT_OPERATOR', '=>')
#                   ])
#                 ])
#               ])
#             ]),
#             Token('MATH_BLOCK_DELIMITER', '`')
#           ]),
#           Tree(Token('RULE', 'text'), [
#             Token('INLINE_WHITESPACE', ' '),
#             Token('WORD', 'show'),
#             Token('INLINE_WHITESPACE', ' '),
#             Token('WORD', 'that')
#           ]),
#           Token('INLINE_WHITESPACE', ' '),
#           Tree(Token('RULE', 'math_block'), [
#             Token('MATH_BLOCK_DELIMITER', '`'),
#             Tree(Token('RULE', 'math_content'), [
#               Tree(Token('RULE', 'expression'), [
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('LETTER', 'k')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'operator'), [
#                     Token('SHORTCUT_OPERATOR', '|->')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'sub_super_script_term'), [
#                   Tree(Token('RULE', 'sub_expression'), [
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('LETTER', 'a')
#                       ])
#                     ])
#                   ]),
#                   Token('SUPERSCRIPT_OPERATOR', '^'),
#                   Tree(Token('RULE', 'sub_expression'), [
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('LETTER', 'k')
#                       ])
#                     ])
#                   ])
#                 ])
#               ])
#             ]),
#             Token('MATH_BLOCK_DELIMITER', '`')
#           ]),
#           Tree(Token('RULE', 'text'), [
#             Token('INLINE_WHITESPACE', ' '),
#             Token('WORD', 'is'),
#             Token('INLINE_WHITESPACE', ' '),
#             Token('WORD', 'an')
#           ]),
#           Token('INLINE_WHITESPACE', ' '),
#           Tree(Token('RULE', 'text'), [
#             Token('WORD', 'isomorphism')
#           ]),
#           Token('INLINE_WHITESPACE', ' '),
#           Tree(Token('RULE', 'math_block'), [
#             Token('MATH_BLOCK_DELIMITER', '`'),
#             Tree(Token('RULE', 'math_content'), [
#               Tree(Token('RULE', 'expression'), [
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('MATH_BB_SYMBOLS', 'ℤ')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'operator'), [
#                     Token('SHORTCUT_OPERATOR', '->')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('LETTER', 'G')
#                   ])
#                 ])
#               ])
#             ]),
#             Token('MATH_BLOCK_DELIMITER', '`')
#           ])
#         ])
#       ]),
#       Token('NEWLINE', '\n'),
#       Tree(Token('RULE', 'list_item'), [
#         Tree(Token('RULE', 'list_bullet'), [
#           Token('SIMPLE_LIST_BULLET', '-'),
#           Token('__ANON_0', '2'),
#           Token('__ANON_0', '.')
#         ]),
#         Token('INLINE_WHITESPACE', ' '),
#         Tree(Token('RULE', 'inline_content'), [
#           Tree(Token('RULE', 'math_block'), [
#             Token('MATH_BLOCK_DELIMITER', '`'),
#             Tree(Token('RULE', 'math_content'), [
#               Tree(Token('RULE', 'expression'), [
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('LETTER', 'G')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'operator'), [
#                     Token('UNICODE_OPERATOR', '=')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('MATH_SYMBOLS', '⟨')
#                   ]),
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('LETTER', 'a')
#                   ]),
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('MATH_SYMBOLS', '⟩')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('DOUBLE_SPACE', '  ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'operator'), [
#                     Token('SHORTCUT_OPERATOR', '=>')
#                   ])
#                 ])
#               ])
#             ]),
#             Token('MATH_BLOCK_DELIMITER', '`')
#           ]),
#           Tree(Token('RULE', 'text'), [
#             Token('INLINE_WHITESPACE', ' '),
#             Token('WORD', 'show'),
#             Token('INLINE_WHITESPACE', ' '),
#             Token('WORD', 'that')
#           ]),
#           Token('INLINE_WHITESPACE', ' '),
#           Tree(Token('RULE', 'math_block'), [
#             Token('MATH_BLOCK_DELIMITER', '`'),
#             Tree(Token('RULE', 'math_content'), [
#               Tree(Token('RULE', 'expression'), [
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('LETTER', 'k')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'operator'), [
#                     Token('SHORTCUT_OPERATOR', '|->')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'sub_super_script_term'), [
#                   Tree(Token('RULE', 'sub_expression'), [
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('LETTER', 'a')
#                       ])
#                     ])
#                   ]),
#                   Token('SUPERSCRIPT_OPERATOR', '^'),
#                   Tree(Token('RULE', 'sub_expression'), [
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('LETTER', 'k')
#                       ])
#                     ])
#                   ])
#                 ])
#               ])
#             ]),
#             Token('MATH_BLOCK_DELIMITER', '`')
#           ]),
#           Tree(Token('RULE', 'text'), [
#             Token('INLINE_WHITESPACE', ' '),
#             Token('WORD', 'is')
#           ]),
#           Tree(Token('RULE', 'text'), [
#             Token('INLINE_WHITESPACE', ' '),
#             Token('WORD', 'an'),
#             Token('INLINE_WHITESPACE', ' '),
#             Token('WORD', 'isomorphism')
#           ]),
#           Token('INLINE_WHITESPACE', ' '),
#           Tree(Token('RULE', 'math_block'), [
#             Token('MATH_BLOCK_DELIMITER', '`'),
#             Tree(Token('RULE', 'math_content'), [
#               Tree(Token('RULE', 'expression'), [
#                 Tree(Token('RULE', 'sub_super_script_term'), [
#                   Tree(Token('RULE', 'sub_expression'), [
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('MATH_BB_SYMBOLS', 'ℤ')
#                       ])
#                     ])
#                   ]),
#                   Token('SUBSCRIPT_OPERATOR', '_'),
#                   Tree(Token('RULE', 'sub_expression'), [
#                     Tree(Token('RULE', 'term'), [
#                       Tree(Token('RULE', 'symbol'), [
#                         Token('LETTER', 'n')
#                       ])
#                     ])
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'operator'), [
#                     Token('SHORTCUT_OPERATOR', '->')
#                   ])
#                 ]),
#                 Tree(Token('RULE', 'inline_whitespace'), [
#                   Token('SPACE', ' ')
#                 ]),
#                 Tree(Token('RULE', 'term'), [
#                   Tree(Token('RULE', 'symbol'), [
#                     Token('LETTER', 'G')
#                   ])
#                 ])
#               ])
#             ]),
#             Token('MATH_BLOCK_DELIMITER', '`')
#           ])
#         ])
#       ])
#     ])
#   ])
